# %%
import matplotlib.pyplot as plt
import numpy as np
#color variable
gray_color="#7f7f7f"
primary_color="#0da2cc"
secondary_color="#6eb819"
tertiary_color="#fd602e"
black_color="#4c4f54"
white_color="#ffffff"

#linestyle
solid='solid'
ldashed=(0,(5,10))
dashed='dashed'

## notice the index of linestyle
ls_list=[solid,ldashed,dashed]

#### 3 change the linestyle ####
l_a=0
l_b=0
l_c=2
l_d=2
l_e=2

## notice the index of color
color_list=[gray_color, primary_color,secondary_color,tertiary_color,black_color,white_color]

#### 2 change the color ####
c_a=2
c_b=1
c_c=1
c_d=3
c_e=0

#### 1 chage the variable to limit the axis ####
x_s=-8
x_e=2
y_s=-201
y_e=11

#line-width of axis and lines
lwa=1
lwl=3.3

# size of the figure
plt.figure(figsize=(5,5))

#axes remove border
plt.axes([0,0,1,1], frameon=False)

# use set_position put axis at 0
ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')

#remove tick and color label
plt.tick_params(left=False)
plt.tick_params(bottom=False)
plt.tick_params(colors=color_list[4])

#get the tick for origin
z_x=0
z_y=1

#remove zero
xticks = ax.xaxis.get_major_ticks()
yticks = ax.yaxis.get_major_ticks()
xticks[z_x].label1.set_visible(False)
yticks[z_y].label1.set_visible(False)

x_l = ax.xaxis.get_ticks_position()
print(x_l)
#add 0 manually
plt.text(0-(x_e-x_s)/25,0-(y_e-y_s)/25,'0',color=color_list[4])

#limit the axis
plt.xlim([x_s,x_e])
plt.ylim([y_s,y_e])


#ploting axis
plt.grid(color='#c0c0c0',linestyle=ls_list[1])
plt.plot([x_s,x_e],[0,0],color="#4c4f54",linewidth=lwa)
plt.plot([0,0],[y_s,y_e],color=color_list[0],linewidth=lwa)

# x value
x=np.linspace(x_s,x_e,100)

#### 0 change ploting function ####

#ploting function
a=100*np.cos(x)
plt.plot(x,a,color=color_list[c_a],linewidth=lwl,linestyle=ls_list[l_a],alpha=.7)

#ploting function
b=100*np.sin(x)
plt.plot(x,b,color=color_list[c_b],linewidth=lwl,linestyle=ls_list[l_b],alpha=.7)

#ploting function
c=100*np.tan(x)
plt.plot(x,c,color=color_list[c_c],linewidth=lwl,linestyle=ls_list[l_c],alpha=.7)

#ploting function
d=100/(np.sin(x))
#plt.plot(x,d,color=color_list[c_d],linewidth=lwl,linestyle=ls_list[l_d],alpha=.7)

#ploting function
e=100/np.cos(x)
plt.plot(x,e,color=color_list[c_e],linewidth=lwl,linestyle=ls_list[l_e],alpha=.7)

#ploting points
#list_of_x=np.zeros(6)-(x_e-x_s)/90
#list_of_y=np.arange(y_s,int(y_e+(y_e-y_s)/5),int((y_e-y_s)/5))
#for a_x_from_list,a_y_from_list in zip(list_of_x[1:5], list_of_y[1:5]): 
#    if a_y_from_list !=0:
#        plt.text(a_x_from_list, a_y_from_list, str(a_y_from_list),ha='right',color=color_list[4],va='center')
#    else:
#        plt.text(a_x_from_list,a_y_from_list-(y_e-y_s)/25,str(0),ha='right',color=color_list[4])
#list_of_y=np.zeros(6)-(y_e-y_s)/30
#list_of_x=np.arange(x_s,int(x_e+(x_e-x_s)/5),int((x_e-x_s)/5))
#for a_x_from_list,a_y_from_list in zip(list_of_x[1:5], list_of_y[1:5]): 
#    if a_x_from_list !=0:
#        plt.text(a_x_from_list, a_y_from_list, str(a_x_from_list),ha='right',color=color_list[4],va='center')

plt.savefig('k.png')
plt.show()
# Out:
# unknown

# %%
round(abs(y_s/((y_e-y_s)/5))+1)
# Out:
# 4

# %%
round(abs(x_s/((x_e-x_s)/5))+1)
# Out:
# 5
